# %% [markdown]
# ### Notebook accompanying  the Scientific Computing Lecture
# #### Tutorial by [Shijian Xu](https://bmda.dmi.unibas.ch/people/shijian.xu/)
# #### University of Basel [Department of Mathematics and Computer Science](https://dmi.unibas.ch/en/)

# %% [markdown]
# # Exercise 2.2 Cholesky Decomposition

# %%
## TO DO: Implement the Cholesky Decomposion for the matrix A.
